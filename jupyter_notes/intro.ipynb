# %%
from IPython import display
display.Image("img/1.PNG")

# %% [markdown]
# Los sensores son los que se necesitan para tomar muestras del entorno, son los que contactan con el exterior.
#
# La forma en que se contacta con el turista puede ser al presionar un boton o, por sensores de presencia. Hay que considerar lo que consuma mucho menos energia para que sea un mantenimiento sostenible, tanto en hardware como en software.
#
# Por otra parte los actuadores son los que ejecutan acciones. Aqui entran los relay para abrir o cerrar puertas, un calefactor que caliente un tanque de aqua por ejemplo.

# %%
from IPython import display
display.Image("img/2.PNG")

# %% [markdown]
# Por otra parte estan las aplicaciones que como usuario me permiten ver los resultados de la informacion. Y me convierto en un actor sobre el medio ambiente.
#
#
# Entonces se tienen dos elementos, uno a cada lado del servidor, y todo cobra mucho mas sentido.
#
# El servidor es un intermediario entre los dispositivos y las aplicaciones . llevando y trayendo informacion.

# %%
from IPython import display
display.Image("img/3.PNG")

# %% [markdown]
# Necesito una base de datos para guardar la informacion de los usuarios y poder accder a ella en el tiempo.
#
# Tomar lecturas y puedo guardar los datos en una base de datos para su posterior analisis.
#
# Este es el sistema IOT mas básico.
#
# La parte del servidor es un mundo aparte que se tiene que mantener. Es la parte que requiere mas tiempo.
#
# La forma mas facil es utilizar servicios de terceros y con unos pocos click ya tengamos funcionando esa parte.
#
# Como Amazon Web Services.
#
# Va a llegar el momento en donde ons demos cuenta que el movimiento IOT de capital es la INDUSTRIA
#
# Llega el momento en donde tenga que desarrollar algo desde 0, eficaz y seguro.
#
# No queremos que colapse el sistema por no tener la robustez suficiente.

# %% [markdown]
# ### Reglas OFF LINE

# %%
from IPython import display
display.Image("img/4.PNG")

# %% [markdown]
# Tenemos dispositivos que esten controlando tareas o procesos.
#
# Es normal tener REGLAS en el servidor, para que controle los valores y en funcion de lo que pase actue o no.
#
# NO podemos dejar todo en manos del internet, porque el internet se corta, como se corta la energia electrica.
#
# Entonces porque se corte el internet no podemos dejar de prestar el servicio, como las cerraduras electricas.
#
# Necesitamos un servicio OFF LINE con un minimo de prestaciones. Lo minimo indispensable tienie que seguir funcionando.
#
#
# Por ejemplo si el servidor detecta que uno de los SENSORES esta enviado un valor anormal, enviara una alarma a las aplicaciones.

# %% [markdown]
# ## Seguridad

# %%
from IPython import display
display.Image("img/5.PNG")

# %% [markdown]
# Super importante la seguridad que tiene que tenenr el servidor y todas las partes que intervienen en el sistema IOT.
