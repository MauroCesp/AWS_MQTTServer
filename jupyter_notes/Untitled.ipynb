# %% [markdown]
# ## SSH connection

# %% [markdown]
# NOs conectamos con Putty
#
# Se descargan dos programas: la terminal de PUtty, y PuttyGen
#
#     Se generaron llaves una llave public ay otra privada al momento de crear el VPS en AWS.

# %%
from IPython import display
display.Image("img/22.PNG")

# %% [markdown]
# Se descargo el archivo al ordenador con la llave privada. Una vez descargada nunca mas de podra descargar de nueov.
#
# En el caso de que se pierda el arvhico o esta en manos equivocadas creamos otra llave.
#
# La ruta en el ordenador donde se guarde la llave es coda de cada uno.
#
# En LInux se puede conectar directo de la terminal de Linux. Pero en WIndows tiene que ser por medio de windows.

# %% [markdown]
# ### TIPO de connection
#
# El tipo de coneccion va a ser sin clave , es decir que no excribimos clave. Usamos la clave privada.
#
# El problema es que pUtty no reconoce el archivo PEM como tal, hay que transformarlo. Se hace una vez

# %% [markdown]
# ### Putty Gen
#
# Conversion > IMportar Llave > Selct the key
#
# Una vez seleccionada la llave sin tocar nada se hace click en "save private key". Tener cuidado de no grabar la publica.

# %%
from IPython import display
display.Image("img/23.PNG")

# %% [markdown]
# ### Putty
#
# Ya puedo conectarme, puedo utilizar el host name o la IP.
#
# Como tenemos IP fija (Elastic IP)la podemos utiliar.
#
# Es necesario seleccionar la llave private convertida a PPK, de la siguiente manera.

# %%
from IPython import display
display.Image("img/24.PNG")
